# %%
import joblib
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %%
loaded_model = joblib.load('my_model.pkl')

# %%
print(loaded_model.predict(
    np.array(
        [[205, 80, 51, 4.2, 4.1, 21, 174, 91, 118.0, 59.0, 46.0, 48.0, 30, False, True]]
    )
))
# Out:
# [False]
